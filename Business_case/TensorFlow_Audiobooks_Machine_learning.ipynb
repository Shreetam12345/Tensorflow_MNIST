# %% [markdown]
# # Audiobooks business case

# %%
import numpy as np

# Create a class that will do the batching for the algorithm
# This code is extremely reusable. You should just change Audiobooks_data everywhere in the code
class Audiobooks_Data_Reader():
    # Dataset is a mandatory arugment, while the batch_size is optional
    # If you don't input batch_size, it will automatically take the value: None
    def __init__(self, dataset, batch_size = None):
    
        # The dataset that loads is one of "train", "validation", "test".
        # e.g. if I call this class with x('train',5), it will load 'Audiobooks_data_train.npz' with a batch size of 5.
        npz = np.load('Audiobooks_data_{0}.npz'.format(dataset))
        
        # Two variables that take the values of the inputs and the targets. Inputs are floats, targets are integers
        self.inputs, self.targets = npz['inputs'].astype(float), npz['targets'].astype(int)

        
        # Counts the batch number, given the size you feed it later
        # If the batch size is None, we are either validating or testing, so we want to take the data in a single batch
        if batch_size is None:
            self.batch_size = self.inputs.shape[0]
        else:
            self.batch_size = batch_size
        self.curr_batch = 0
        self.batch_count = self.inputs.shape[0] // self.batch_size
    
    # A method which loads the next batch
    def __next__(self):
        if self.curr_batch >= self.batch_count:
            self.curr_batch = 0
            raise StopIteration()
            
        # You slice the dataset in batches and then the "next" function loads them one after the other
        batch_slice = slice(self.curr_batch * self.batch_size, (self.curr_batch + 1) * self.batch_size)
        inputs_batch = self.inputs[batch_slice]
        targets_batch = self.targets[batch_slice]
        self.curr_batch += 1
        
        # One-hot encode the targets. In this example it's a bit superfluous since we have a 0/1 column 
        # as a target already but we're giving you the code regardless, as it will be useful for any 
        # classification task with more than one target column
        classes_num = 2
        targets_one_hot = np.zeros((targets_batch.shape[0], classes_num))
        targets_one_hot[range(targets_batch.shape[0]), targets_batch] = 1
        
        # The function will return the inputs batch and the one-hot encoded targets
        return inputs_batch, targets_one_hot
    
        
    # A method needed for iterating over the batches, as we will put them in a loop
    # This tells Python that the class we're defining is iterable, i.e. that we can use it like:
    # for input, output in data: 
        # do things
    # An iterator in Python is a class with a method __next__ that defines exactly how to iterate through its objects
    def __iter__(self):
        return self

# %% [markdown]
# ## Creating the machine learning algorithm

# %%
# We need to import TF (we didn't need it so far)
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()


# Input size depends on the number of input variables. We have 10 of them
input_size = 10
# Output size is 2, as we one-hot encoded the targets.
output_size = 2
# Choose a hidden_layer_size
hidden_layer_size = 50

# Reset the default graph, so you can fiddle with the hyperparameters and then rerun the code.
tf.reset_default_graph()

# Create the placeholders
inputs = tf.placeholder(tf.float32, [None, input_size])
targets = tf.placeholder(tf.int32, [None, output_size])

# Outline the model. We will create a net with 2 hidden layers
weights_1 = tf.get_variable("weights_1", [input_size, hidden_layer_size])
biases_1 = tf.get_variable("biases_1", [hidden_layer_size])
outputs_1 = tf.nn.relu(tf.matmul(inputs, weights_1) + biases_1)

weights_2 = tf.get_variable("weights_2", [hidden_layer_size, hidden_layer_size])
biases_2 = tf.get_variable("biases_2", [hidden_layer_size])
outputs_2 = tf.nn.sigmoid(tf.matmul(outputs_1, weights_2) + biases_2)

weights_3 = tf.get_variable("weights_3", [hidden_layer_size, output_size])
biases_3 = tf.get_variable("biases_3", [output_size])
# We will incorporate the softmax activation into the loss, as in the previous example
outputs = tf.matmul(outputs_2, weights_3) + biases_3

# Use the softmax cross entropy loss with logits
loss = tf.nn.softmax_cross_entropy_with_logits(logits=outputs, labels=targets)
mean_loss = tf.reduce_mean(loss)

# Get a 0 or 1 for every input indicating whether it output the correct answer
out_equals_target = tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(out_equals_target, tf.float32))

# Optimize with Adam
optimize = tf.train.AdamOptimizer(learning_rate=0.0001).minimize(mean_loss)

# Create a session
sess = tf.InteractiveSession()

# Initialize the variables
initializer = tf.global_variables_initializer()
sess.run(initializer)

# Choose the batch size
batch_size = 100

# Set early stopping mechanisms
max_epochs = 100
prev_validation_loss = 9999999.

# Load the first batch of training and validation, using the class we created. 
# Arguments are ending of 'Audiobooks_Data_<...>', where for <...> we input 'train', 'validation', or 'test'
# depending on what we want to load
train_data = Audiobooks_Data_Reader('train', batch_size)
validation_data = Audiobooks_Data_Reader('validation')

# Create the loop for epochs 
for epoch_counter in range(max_epochs):
    
    # Set the epoch loss to 0, and make it a float
    curr_epoch_loss = 0.
    
    # Iterate over the training data 
    # Since train_data is an instance of the Audiobooks_Data_Reader class,
    # we can iterate through it by implicitly using the __next__ method we defined above.
    # As a reminder, it batches samples together, one-hot encodes the targets, and returns
    # inputs and targets batch by batch
    for input_batch, target_batch in train_data:
        _, batch_loss = sess.run([optimize, mean_loss], 
            feed_dict={inputs: input_batch, targets: target_batch})
        
        #Record the batch loss into the current epoch loss
        curr_epoch_loss += batch_loss
    
    # Find the mean curr_epoch_loss
    # batch_count is a variable, defined in the Audiobooks_Data_Reader class
    curr_epoch_loss /= train_data.batch_count
    
    # Set validation loss and accuracy for the epoch to zero
    validation_loss = 0.
    validation_accuracy = 0.
    
    # Use the same logic of the code to forward propagate the validation set
    # There will be a single batch, as the class was created in this way
    for input_batch, target_batch in validation_data:
        validation_loss, validation_accuracy = sess.run([mean_loss, accuracy],
            feed_dict={inputs: input_batch, targets: target_batch})
    
    # Print statistics for the current epoch
    print('Epoch '+str(epoch_counter+1)+
          '. Training loss: '+'{0:.3f}'.format(curr_epoch_loss)+
          '. Validation loss: '+'{0:.3f}'.format(validation_loss)+
          '. Validation accuracy: '+'{0:.2f}'.format(validation_accuracy * 100.)+'%')
    
    # Trigger early stopping if validation loss begins increasing.
    if validation_loss > prev_validation_loss:
        break
        
    # Store this epoch's validation loss to be used as previous in the next iteration.
    prev_validation_loss = validation_loss
    
print('End of training.')
# Out:
# ERROR:tensorflow:An interactive session is already active. This can cause out-of-memory errors or some other unexpected errors (due to the unpredictable timing of garbage collection) in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s). Please use `tf.Session()` if you intend to productionize.
# Epoch 1. Training loss: 1.508. Validation loss: 1.339. Validation accuracy: 53.02%
# Epoch 2. Training loss: 1.381. Validation loss: 1.226. Validation accuracy: 53.02%
# Epoch 3. Training loss: 1.261. Validation loss: 1.120. Validation accuracy: 53.02%
# Epoch 4. Training loss: 1.149. Validation loss: 1.022. Validation accuracy: 53.02%
# Epoch 5. Training loss: 1.047. Validation loss: 0.935. Validation accuracy: 53.02%
# Epoch 6. Training loss: 0.956. Validation loss: 0.860. Validation accuracy: 53.24%
# Epoch 7. Training loss: 0.877. Validation loss: 0.796. Validation accuracy: 52.80%
# Epoch 8. Training loss: 0.812. Validation loss: 0.745. Validation accuracy: 53.47%
# Epoch 9. Training loss: 0.759. Validation loss: 0.705. Validation accuracy: 54.81%
# Epoch 10. Training loss: 0.717. Validation loss: 0.674. Validation accuracy: 57.05%
# Epoch 11. Training loss: 0.684. Validation loss: 0.651. Validation accuracy: 59.73%
# Epoch 12. Training loss: 0.659. Validation loss: 0.634. Validation accuracy: 63.09%
# Epoch 13. Training loss: 0.640. Validation loss: 0.621. Validation accuracy: 64.65%
# Epoch 14. Training loss: 0.624. Validation loss: 0.610. Validation accuracy: 67.79%
# Epoch 15. Training loss: 0.612. Validation loss: 0.601. Validation accuracy: 69.57%
# Epoch 16. Training loss: 0.601. Validation loss: 0.593. Validation accuracy: 69.35%
# Epoch 17. Training loss: 0.592. Validation loss: 0.586. Validation accuracy: 70.47%
# Epoch 18. Training loss: 0.583. Validation loss: 0.580. Validation accuracy: 70.02%
# Epoch 19. Training loss: 0.575. Validation loss: 0.573. Validation accuracy: 70.92%
# Epoch 20. Training loss: 0.568. Validation loss: 0.568. Validation accuracy: 70.02%
# Epoch 21. Training loss: 0.562. Validation loss: 0.562. Validation accuracy: 70.02%
# Epoch 22. Training loss: 0.555. Validation loss: 0.557. Validation accuracy: 70.02%
# Epoch 23. Training loss: 0.549. Validation loss: 0.551. Validation accuracy: 69.13%
# Epoch 24. Training loss: 0.543. Validation loss: 0.546. Validation accuracy: 68.01%
# Epoch 25. Training loss: 0.538. Validation loss: 0.542. Validation accuracy: 67.79%
# Epoch 26. Training loss: 0.533. Validation loss: 0.537. Validation accuracy: 68.23%
# Epoch 27. Training loss: 0.528. Validation loss: 0.532. Validation accuracy: 67.56%
# Epoch 28. Training loss: 0.523. Validation loss: 0.528. Validation accuracy: 68.46%
# Epoch 29. Training loss: 0.518. Validation loss: 0.524. Validation accuracy: 68.90%
# Epoch 30. Training loss: 0.513. Validation loss: 0.520. Validation accuracy: 69.57%
# Epoch 31. Training loss: 0.509. Validation loss: 0.516. Validation accuracy: 69.57%
# Epoch 32. Training loss: 0.505. Validation loss: 0.512. Validation accuracy: 69.80%
# Epoch 33. Training loss: 0.501. Validation loss: 0.508. Validation accuracy: 69.80%
# Epoch 34. Training loss: 0.497. Validation loss: 0.504. Validation accuracy: 70.47%
# Epoch 35. Training loss: 0.493. Validation loss: 0.501. Validation accuracy: 70.69%
# Epoch 36. Training loss: 0.489. Validation loss: 0.498. Validation accuracy: 70.92%
# Epoch 37. Training loss: 0.486. Validation loss: 0.494. Validation accuracy: 71.36%
# Epoch 38. Training loss: 0.482. Validation loss: 0.491. Validation accuracy: 71.81%
# Epoch 39. Training loss: 0.479. Validation loss: 0.488. Validation accuracy: 71.81%
# Epoch 40. Training loss: 0.476. Validation loss: 0.485. Validation accuracy: 72.04%
# Epoch 41. Training loss: 0.472. Validation loss: 0.482. Validation accuracy: 72.26%
# Epoch 42. Training loss: 0.469. Validation loss: 0.479. Validation accuracy: 72.26%
# Epoch 43. Training loss: 0.466. Validation loss: 0.476. Validation accuracy: 72.48%
# Epoch 44. Training loss: 0.464. Validation loss: 0.474. Validation accuracy: 72.71%
# Epoch 45. Training loss: 0.461. Validation loss: 0.471. Validation accuracy: 74.94%
# Epoch 46. Training loss: 0.458. Validation loss: 0.468. Validation accuracy: 76.06%
# Epoch 47. Training loss: 0.455. Validation loss: 0.466. Validation accuracy: 77.40%
# Epoch 48. Training loss: 0.453. Validation loss: 0.464. Validation accuracy: 77.63%
# Epoch 49. Training loss: 0.451. Validation loss: 0.461. Validation accuracy: 78.52%
# Epoch 50. Training loss: 0.448. Validation loss: 0.459. Validation accuracy: 78.97%
# Epoch 51. Training loss: 0.446. Validation loss: 0.457. Validation accuracy: 80.09%
# Epoch 52. Training loss: 0.444. Validation loss: 0.454. Validation accuracy: 79.87%
# Epoch 53. Training loss: 0.441. Validation loss: 0.452. Validation accuracy: 80.31%
# Epoch 54. Training loss: 0.439. Validation loss: 0.450. Validation accuracy: 80.76%
# Epoch 55. Training loss: 0.437. Validation loss: 0.448. Validation accuracy: 80.31%
# Epoch 56. Training loss: 0.435. Validation loss: 0.446. Validation accuracy: 80.09%
# Epoch 57. Training loss: 0.433. Validation loss: 0.444. Validation accuracy: 79.87%
# Epoch 58. Training loss: 0.431. Validation loss: 0.442. Validation accuracy: 80.54%
# Epoch 59. Training loss: 0.430. Validation loss: 0.440. Validation accuracy: 80.54%
# Epoch 60. Training loss: 0.428. Validation loss: 0.438. Validation accuracy: 80.09%
# Epoch 61. Training loss: 0.426. Validation loss: 0.437. Validation accuracy: 80.31%
# Epoch 62. Training loss: 0.424. Validation loss: 0.435. Validation accuracy: 80.09%
# Epoch 63. Training loss: 0.423. Validation loss: 0.433. Validation accuracy: 80.09%
# Epoch 64. Training loss: 0.421. Validation loss: 0.431. Validation accuracy: 80.31%
# Epoch 65. Training loss: 0.419. Validation loss: 0.430. Validation accuracy: 80.31%
# Epoch 66. Training loss: 0.418. Validation loss: 0.428. Validation accuracy: 80.31%
# Epoch 67. Training loss: 0.416. Validation loss: 0.427. Validation accuracy: 80.31%
# Epoch 68. Training loss: 0.415. Validation loss: 0.425. Validation accuracy: 80.54%
# Epoch 69. Training loss: 0.413. Validation loss: 0.423. Validation accuracy: 80.31%
# Epoch 70. Training loss: 0.412. Validation loss: 0.422. Validation accuracy: 80.09%
# Epoch 71. Training loss: 0.410. Validation loss: 0.420. Validation accuracy: 80.09%
# Epoch 72. Training loss: 0.409. Validation loss: 0.419. Validation accuracy: 80.54%
# Epoch 73. Training loss: 0.408. Validation loss: 0.417. Validation accuracy: 80.54%
# Epoch 74. Training loss: 0.406. Validation loss: 0.416. Validation accuracy: 80.54%
# Epoch 75. Training loss: 0.405. Validation loss: 0.415. Validation accuracy: 80.98%
# Epoch 76. Training loss: 0.404. Validation loss: 0.413. Validation accuracy: 81.43%
# Epoch 77. Training loss: 0.402. Validation loss: 0.412. Validation accuracy: 81.66%
# Epoch 78. Training loss: 0.401. Validation loss: 0.411. Validation accuracy: 81.66%
# Epoch 79. Training loss: 0.400. Validation loss: 0.409. Validation accuracy: 81.66%
# Epoch 80. Training loss: 0.399. Validation loss: 0.408. Validation accuracy: 81.66%
# Epoch 81. Training loss: 0.397. Validation loss: 0.407. Validation accuracy: 81.43%
# Epoch 82. Training loss: 0.396. Validation loss: 0.405. Validation accuracy: 81.66%
# Epoch 83. Training loss: 0.395. Validation loss: 0.404. Validation accuracy: 81.66%
# Epoch 84. Training loss: 0.394. Validation loss: 0.403. Validation accuracy: 81.66%
# Epoch 85. Training loss: 0.393. Validation loss: 0.402. Validation accuracy: 81.66%
# Epoch 86. Training loss: 0.392. Validation loss: 0.400. Validation accuracy: 81.66%
# Epoch 87. Training loss: 0.391. Validation loss: 0.399. Validation accuracy: 81.66%
# Epoch 88. Training loss: 0.389. Validation loss: 0.398. Validation accuracy: 81.88%
# Epoch 89. Training loss: 0.388. Validation loss: 0.397. Validation accuracy: 81.88%
# Epoch 90. Training loss: 0.387. Validation loss: 0.396. Validation accuracy: 81.88%
# Epoch 91. Training loss: 0.386. Validation loss: 0.395. Validation accuracy: 81.88%
# Epoch 92. Training loss: 0.385. Validation loss: 0.393. Validation accuracy: 81.88%
# Epoch 93. Training loss: 0.384. Validation loss: 0.392. Validation accuracy: 82.10%
# Epoch 94. Training loss: 0.383. Validation loss: 0.391. Validation accuracy: 82.10%
# Epoch 95. Training loss: 0.382. Validation loss: 0.390. Validation accuracy: 82.10%
# Epoch 96. Training loss: 0.381. Validation loss: 0.389. Validation accuracy: 82.33%
# Epoch 97. Training loss: 0.381. Validation loss: 0.388. Validation accuracy: 82.10%
# Epoch 98. Training loss: 0.380. Validation loss: 0.387. Validation accuracy: 82.10%
# Epoch 99. Training loss: 0.379. Validation loss: 0.386. Validation accuracy: 82.10%
# Epoch 100. Training loss: 0.378. Validation loss: 0.385. Validation accuracy: 82.10%
# End of training.

# %% [markdown]
# ## Testing the model

# %%
# Load the test data, following the same logic as we did for the train_data and validation data
test_data = Audiobooks_Data_Reader('test')

# Forward propagate through the training set. This time we only need the accuracy
for inputs_batch, targets_batch in test_data:
    test_accuracy = sess.run([accuracy],
                     feed_dict={inputs: inputs_batch, targets: targets_batch})

# Get the test accuracy in percentages
# When sess.run is has a single output, we get a list (that's how it was coded by Google), rather than a float.
# Therefore, we must take the first value from the list (the value at position 0)
test_accuracy_percent = test_accuracy[0] * 100.

# Print the test accuracy
print('Test accuracy: '+'{0:.2f}'.format(test_accuracy_percent)+'%')
# Out:
# Test accuracy: 78.12%
